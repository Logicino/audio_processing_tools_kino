# %%
import matplotlib.pyplot as plt 
import numpy as np 

data = np.load('/data/xyth/query_based_source_separation/data_npy/length.npy')
plt.hist(data, bins=100)

data = np.sort(data)
print(len(data))
gate = data[int(len(data) * 0.9)]

print(gate)
plt.show()
# Out:
# 149
# 174.57439583333334
